# %%
import os
import zipfile
import pandas as pd

d={"username":"aytenmerdeliyeva","key":"e713c2d3946efd217b31e97c4bb1654d"}
os.environ['KAGGLE_USERNAME'] = d["username"]
os.environ['KAGGLE_KEY'] = d["key"]

# %%
# !pip install kaggle
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !kaggle datasets download -d ericanacletoribeiro/cicids2017-cleaned-and-preprocessed
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ericanacletoribeiro/cicids2017-cleaned-and-preprocessed
#   0%|          | 0.00/200M [00:00<?, ?B/s]
#  21%|██▏       | 43.0M/200M [00:00<00:00, 449MB/s]
#  55%|█████▌    | 111M/200M [00:00<00:00, 598MB/s]
#  89%|████████▉ | 178M/200M [00:00<00:00, 643MB/s]
# 100%|██████████| 200M/200M [00:00<00:00, 618MB/s]
# License(s): CC0-1.0
# ...

# %%
with zipfile.ZipFile("cicids2017-cleaned-and-preprocessed.zip", 'r') as zip_ref:
    zip_ref.extractall("data")
